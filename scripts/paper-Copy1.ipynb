# %% [markdown]
# ## Paper

# %%
from matplotlib import pyplot as plt
import numpy as np

from predhpc import paper
from predhpc.util import plot_util

# %load_ext autoreload

# %%
# %autoreload 2

# %%
paper.initialize_paper_parameters(gen_dir="..", notebook=True)
ALL_FIGURES = dict()

# %% [markdown]
# ### Fig. 1: Background

# %%
fig, panel = 1, "B"
ALL_FIGURES[f"{fig}{panel}"] = paper.plot_figure_panel(fig=fig, panel=panel)
# Out:
# Figure saved to /home/cgillon/homedir/predhpc/results/paper/1B.png  & .svg

# %%
fig, panel = 1, "D"
ALL_FIGURES[f"{fig}{panel}"] = paper.plot_figure_panel(fig=fig, panel=panel)
# Out:
# Figure saved to /home/cgillon/homedir/predhpc/results/paper/1D.png  & .svg

# %% [markdown]
# ### Fig. 2: Linear track
# With this seed, BTSP event is recorded at step 513 and applied at step 1207.

# %%
linear_learner = paper.run_linear(max_time_min=2.0)
# Out:
#  15%|█████▊                                 | 602/4000 [00:00<00:04, 696.17it/s]
# BTSP event recorded at step 513 (15.39 sec).
#  30%|███████████▍                          | 1201/4000 [00:01<00:03, 741.97it/s]
# BTSP update applied at step 1207 (36.21 sec).
# 100%|██████████████████████████████████████| 4000/4000 [00:05<00:00, 688.74it/s]
# Completing last trajectory.
# 1278it [00:01, 680.69it/s]
# Only reached target 4 times (target: 10).
# Trajectory lengths (5): 31.67 +/- 17.74 sec each
# Trajectory lengths (5): 1055.80 +/- 591.42 steps each
# 1 BTSP event triggered (allowed from steps 0 to 5278): occurred at step 513.
# No weight normalization applied (max value of 0.7783 <= 1).

# %%
fig, panel = 2, "A"
ALL_FIGURES[f"{fig}{panel}"] = paper.plot_figure_panel(linear_learner, fig=fig, panel=panel)
# Out:
# Figure saved to /home/cgillon/homedir/predhpc/results/paper/2A.png  & .svg

# %%
fig, panel = 2, "B"
ALL_FIGURES[f"{fig}{panel}"] = paper.plot_figure_panel(linear_learner, fig=fig, panel=panel)
# Out:
# Figure saved to /home/cgillon/homedir/predhpc/results/paper/2B.png  & .svg

# %%
fig, panel = 2, "C"
ALL_FIGURES[f"{fig}{panel}"] = paper.plot_figure_panel(linear_learner, fig=fig, panel=panel)
# Out:
# Figure saved to /home/cgillon/homedir/predhpc/results/paper/2C.png  & .svg

# %% [markdown]
# ### Fig. S2: Balanced, excess and insufficient inhibition
# **Balanced:** With this seed, a BTSP event is recorded at step 513.

# %%
balanced_learner = paper.run_linear(max_time_min=2.0, inhibition="balanced")
# Out:
#  15%|█████▉                                 | 613/4000 [00:00<00:04, 755.78it/s]
# BTSP event recorded at step 513 (15.39 sec).
#  32%|████████████▎                         | 1297/4000 [00:01<00:03, 753.36it/s]
# BTSP update applied at step 1207 (36.21 sec).
# 100%|██████████████████████████████████████| 4000/4000 [00:05<00:00, 675.59it/s]
# Completing last trajectory.
# 1278it [00:01, 746.73it/s]
# Only reached target 4 times (target: 10).
# Trajectory lengths (5): 31.67 +/- 17.74 sec each
# Trajectory lengths (5): 1055.80 +/- 591.42 steps each
# 1 BTSP event triggered (allowed from steps 0 to 5278): occurred at step 513.
# No weight normalization applied (max value of 0.7783 <= 1).

# %%
fig, panel = "2S", "A"
ALL_FIGURES[f"{fig}{panel}"] = paper.plot_figure_panel(balanced_learner, fig=fig, panel=panel)
# Out:
# Figure saved to /home/cgillon/homedir/predhpc/results/paper/2SA.png  & .svg

# %% [markdown]
# **Insufficient:** With this seed, BTSP events are recorded at steps 512, 2006, 3486 and 4974.

# %%
insufficient_learner = paper.run_linear(max_time_min=2.0, inhibition="insufficient")
# Out:
# Using insufficient inhibition (weight: 0.50).
#  15%|█████▉                                 | 609/4000 [00:00<00:04, 750.68it/s]
# BTSP event recorded at step 512 (15.36 sec).
#  32%|████████████▎                         | 1291/4000 [00:01<00:03, 753.30it/s]
# BTSP update applied at step 1206 (36.18 sec).
#  53%|████████████████████▏                 | 2126/4000 [00:03<00:03, 612.14it/s]
# BTSP event recorded at step 2006 (60.18 sec).
#  70%|██████████████████████████▋           | 2805/4000 [00:04<00:01, 747.58it/s]
# BTSP update applied at step 2700 (81.00 sec).
#  89%|█████████████████████████████████▉    | 3568/4000 [00:05<00:00, 752.12it/s]
# BTSP event recorded at step 3485 (104.55 sec).
# 100%|██████████████████████████████████████| 4000/4000 [00:05<00:00, 693.51it/s]
# Completing last trajectory.
# 301it [00:00, 753.38it/s]
# BTSP update applied at step 4179 (125.37 sec).
# 1068it [00:01, 753.67it/s]
# BTSP event recorded at step 4973 (149.19 sec).
# 1278it [00:01, 752.01it/s]
# ...

# %%
fig, panel = "2S", "B"
ALL_FIGURES[f"{fig}{panel}"] = paper.plot_figure_panel(insufficient_learner, fig=fig, panel=panel)
# Out:
# Figure saved to /home/cgillon/homedir/predhpc/results/paper/2SB.png  & .svg

# %% [markdown]
# **Excessive:** With this seed, no BTSP events are recorded.

# %%
excessive_learner = paper.run_linear(max_time_min=2.0, inhibition="excessive")
# Out:
# Using excessive inhibition (weight: 2.00).
# 100%|██████████████████████████████████████| 4000/4000 [00:05<00:00, 680.53it/s]
# Completing last trajectory.
# 1278it [00:02, 537.25it/s]
# Only reached target 4 times (target: 10).
# Trajectory lengths (5): 31.67 +/- 17.74 sec each
# Trajectory lengths (5): 1055.80 +/- 591.42 steps each
# 0 BTSP events triggered (allowed from steps 0 to 5278).
# No weight normalization applied (max value of 0.6958 <= 1).

# %%
fig, panel = "2S", "C"
ALL_FIGURES[f"{fig}{panel}"] = paper.plot_figure_panel(excessive_learner, fig=fig, panel=panel)
# Out:
# Figure saved to /home/cgillon/homedir/predhpc/results/paper/2SC.png  & .svg

# %% [markdown]
# ### Fig. 3: Speed and PF width
# Very fast with multiple cores (30 sec-1 min). Much longer sequentially.

# %%
speed_data = paper.run_linear_fct("linear_speeds", overwrite=True, num_jobs=30)
# Out:
# Deleting ../results/paper/speed_data_18.npz.
# Running...
# ...
# 100%|███████████████████████████████████████████| 29/29 [00:18<00:00,  1.55it/s]
# Saving data to ../results/paper/speed_data_18.npz.
# Time elapsed: 79.74 s.
# No weight normalization applied (max value of 0.9467 <= 1).

# %%
fig, panel = 3, "A"
ALL_FIGURES[f"{fig}{panel}"] = paper.plot_figure_panel(speed_data, fig=fig, panel=panel)
# Out:
# Figure saved to /home/cgillon/homedir/predhpc/results/paper/3A.png  & .svg

# %% [markdown]
# With this seed, the regression equation obtained was: `y = 0.54x + 0.31`.

# %%
fig, panel = 3, "B"
ALL_FIGURES[f"{fig}{panel}"] = paper.plot_figure_panel(speed_data, fig=fig, panel=panel)
# Out:
# Figure saved to /home/cgillon/homedir/predhpc/results/paper/3B.png  & .svg

# %% [markdown]
# ### Fig. 3S: Speed and PF width (weights)

# %%
fig, panel = "3S", "A"
ALL_FIGURES[f"{fig}{panel}"] = paper.plot_figure_panel(speed_data, fig=fig, panel=panel)
# Out:
# Figure saved to /home/cgillon/homedir/predhpc/results/paper/3SA.png  & .svg

# %% [markdown]
# With this seed, the regression equation obtained was: `y = 1.31x + 0.18`.

# %%
fig, panel = "3S", "B"
ALL_FIGURES[f"{fig}{panel}"] = paper.plot_figure_panel(speed_data, fig=fig, panel=panel)
# Out:
# Figure saved to /home/cgillon/homedir/predhpc/results/paper/3SB.png  & .svg

# %% [markdown]
# ### Fig. 4: Effect of linear shifts
# Fast with multiple cores (3-6 min). Much longer sequentially.

# %%
shift_data = paper.run_linear_fct("linear_shifts", overwrite=True, num_jobs=30)
# Out:
# Running...
# ...
# 100%|███████████████████████████████████████████| 61/61 [00:15<00:00,  4.04it/s]
# Saving data to ../results/paper/shift_data_18.npz.
# Time elapsed: 3m 2.83s.
# No weight normalization applied (max value of 0.9580 <= 1).

# %%
fig, panel = 4, "A"
ALL_FIGURES[f"{fig}{panel}"] = paper.plot_figure_panel(shift_data, fig=fig, panel=panel)
# Out:
# Only one BTSP event recorded for shifts to positions between 3.4m and 3.9m.
# Figure saved to /home/cgillon/homedir/predhpc/results/paper/4A.png  & .svg

# %% [markdown]
# ### Fig. S4: Effect of linear shifts
# Fast with multiple cores (3-6 min). Much longer sequentially.

# %%
shift_data = paper.run_linear_fct("linear_shifts", overwrite=False, num_jobs=30)
# Out:
# Loading data from ../results/paper/shift_data_18.npz.
# No weight normalization applied (max value of 0.9580 <= 1).

# %%
fig, panel = "4S", "A"
ALL_FIGURES[f"{fig}{panel}"] = paper.plot_figure_panel(shift_data, fig=fig, panel=panel)
# Out:
# Only one BTSP event recorded for shifts between -0.2m and 0.3m.
# Figure saved to /home/cgillon/homedir/predhpc/results/paper/4SA.png  & .svg

# %% [markdown]
# ### Fig. 5: Openfield corridor
# With this seed, the BTSP event is recorded at step 1097 and applied at step 1791.

# %%
learner = paper.run_openfield_corridor()
# Out:
# ...
#   6%|██                                   | 1147/20000 [00:03<00:54, 348.03it/s]
# BTSP event recorded at step 1097 (32.91 sec).
# ...
#   9%|███▍                                 | 1866/20000 [00:05<00:42, 431.74it/s]
# BTSP update applied at step 1791 (53.73 sec).
# ...
# 100%|████████████████████████████████████| 20000/20000 [00:51<00:00, 384.99it/s]
# Reached target 9 times.
# Trajectory lengths (10): 60.00 +/- 0.00 sec each
# Trajectory lengths (10): 2000.00 +/- 0.00 steps each
# 1 BTSP event triggered (allowed from steps 0 to 19999): occurred at step 1097.
# No weight normalization applied (max value of 0.9721 <= 1).

# %%
fig, panel = 5, "A-D"
ALL_FIGURES[f"{fig}{panel}"] = paper.plot_figure_panel(learner.Pyrs, fig=fig, panel=panel)
# Out:
# Figure saved to /home/cgillon/homedir/predhpc/results/paper/5A-D.png  & .svg

# %%
fig, panel = 5, "E"
ALL_FIGURES[f"{fig}{panel}"] = paper.plot_figure_panel(learner.Pyrs, fig=fig, panel=panel)
# Out:
# Figure saved to /home/cgillon/homedir/predhpc/results/paper/5E.png  & .svg

# %%
fig, panel = 5, "F"
ALL_FIGURES[f"{fig}{panel}"] = paper.plot_figure_panel(learner.Pyrs, fig=fig, panel=panel)
# Out:
# Figure saved to /home/cgillon/homedir/predhpc/results/paper/5F.png  & .svg

# %%
fig, panel = 5, "G"
ALL_FIGURES[f"{fig}{panel}"] = paper.plot_figure_panel(learner.Pyrs, fig=fig, panel=panel)
# Out:
# Figure saved to /home/cgillon/homedir/predhpc/results/paper/5G.png  & .svg

# %% [markdown]
# ### Fig. S5: Openfield corridor

# %%
fig, panel = "5S", "A"
ALL_FIGURES[f"{fig}{panel}"] = paper.plot_figure_panel(learner.Pyrs, fig=fig, panel=panel)
# Out:
# Figure saved to /home/cgillon/homedir/predhpc/results/paper/5SA.png  & .svg

# %%
fig, panel = "5S", "B"
ALL_FIGURES[f"{fig}{panel}"] = paper.plot_figure_panel(learner.Pyrs, fig=fig, panel=panel)
# Out:
# Figure saved to /home/cgillon/homedir/predhpc/results/paper/5SB.png  & .svg

# %% [markdown]
# Run several openfield corridor runs and collect PF information.
# Runs sequentially, to manage memory use, in 8-10 min.

# %%
corridor_data = paper.run_openfield_fct(overwrite=True)
# Out:
# Deleting ../results/paper/corridor_data_18.npz.
# Running...
# ...
#  70%|██████████████████████████████▊             | 7/10 [06:53<02:57, 59.10s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 corridor_data = paper.run_openfield_fct(overwrite=True)
#
# File ~/homedir/predhpc/predhpc/paper.py:1585, in run_openfield_fct(fct_name, num_repeats, overwrite, seed)
#    1583 print("Running...")
#    1584 start_time = time.perf_counter()
# -> 1585 data_dict = fct(seed=seed, num_repeats=num_repeats)
#    1586 gen_util.save_np_dict(save_path, data_dict)
#    1587 gen_util.get_duration_str(start_time, log=True)
#
# File ~/homedir/predhpc/predhpc/paper.py:1296, in run_openfield_corridors(seed, max_num_steps, num_repeats)
#    1294 for i in tqdm(range(num_repeats)):
#    1295     gen_util.seed_all(int(seeds[i]))
# -> 1296     learner = run_openfield_corridor(
# ...

# %%
for key, value in corridor_data.items():
    print(f"{key}: {value.shape}")
# Out:
# PC_place_centers: (400, 2)
# PC_weights: (10, 3, 400)
# PFs: (10, 3, 1600)
# PF_centers: (1600, 2)
# PF_times: (10, 3, 2)
# BTSP_times: (10, 3)
# num_BTSP: (10,)
# visit_times: (10, 25)
# num_visits: (10,)
# norm_values: (10, 3)
# seeds: (10,)

# %%
fig, panel = "5S", "C"
ALL_FIGURES[f"{fig}{panel}"] = paper.plot_figure_panel(corridor_data, fig=fig, panel=panel)
# Out:
# Figure saved to /home/cgillon/homedir/predhpc/results/paper/5SC.png  & .svg

# %%
fig, panel = "5S", "D"
ALL_FIGURES[f"{fig}{panel}"] = paper.plot_figure_panel(corridor_data, fig=fig, panel=panel)
# Out:
# Figure saved to /home/cgillon/homedir/predhpc/results/paper/5SD.png  & .svg

# %% [markdown]
# ### Fig. 6: Teleportation
# With this seed, the first BTSP event is recorded at step 1097 and applied at step 1791.
# Teleportation is enabled at step 20000.
#
# A **first** teleportation event occurs at step 26195.
# A second BTSP event is recorded at step 26200 and applied at step 26894.
#
# A **second** teleportation event occurs at step 32366.
#
# A **third** teleportation event occurs at step 44231.
# A third BTSP event is recorded at step 44235 and applied at step 44929.
#
# A **fourth** teleportation event occurs at step 55265.

# %%
learner_teleport = paper.run_openfield_corridor_teleport()
# Out:
#   6%|██▏                                  | 1149/20000 [00:03<00:51, 363.28it/s]
# BTSP event recorded at step 1097 (32.91 sec).
#   9%|███▍                                 | 1864/20000 [00:05<00:40, 444.53it/s]
# BTSP update applied at step 1791 (53.73 sec).
# 100%|████████████████████████████████████| 20000/20000 [00:54<00:00, 363.77it/s]
# Reached target 9 times.
# Trajectory lengths (10): 60.00 +/- 0.00 sec each
# Trajectory lengths (10): 2000.00 +/- 0.00 steps each
# 1 BTSP event triggered (allowed from steps 0 to 19999): occurred at step 1097.
# No weight normalization applied (max value of 0.9721 <= 1).
#
# Teleportation enabled.
#  31%|███████████▌                         | 6240/20000 [00:19<00:42, 324.64it/s]
# Teleported through pair 0 at step 26195 (785.88 sec.)
# BTSP event recorded at step 26200 (786.00 sec).
#  35%|████████████▊                        | 6947/20000 [00:21<00:42, 310.21it/s]
# BTSP update applied at step 26894 (806.82 sec).
# ...

# %%
fig, panel = "6", "A"
ALL_FIGURES[f"{fig}{panel}"] = paper.plot_figure_panel(learner_teleport, fig=fig, panel=panel)
# Out:
# Figure saved to /home/cgillon/homedir/predhpc/results/paper/6A.png  & .svg

# %% [markdown]
# Supplemental: multiple examples (2 in locations and 2 repeats each?) with different entry ports and out ports:
# near left, far left, near right, far right

# %%
from predhpc import paper

init_teleport_pairs = np.asarray([[[0.6, 0.5], [0.2, 0.1]]])
init_teleport_pairs = np.asarray([[[0.6, 0.5], [0.17, 0.1]]])
init_teleport_pairs = np.asarray([[[0.4, 0.5], [0.3, 0.1]]])
init_teleport_pairs = np.asarray([[[0.4, 0.5], [0.33, 0.1]]])

Pyrs = paper.get_openfield_Pyrs(
    corridor=True, 
    init_reward_only=True, 
    init_teleport_pairs=init_teleport_pairs * 2,
    horizontal_in_from_left=False,
    seed=True, 
    log_BTSP=False
    )

fig, sub_ax = plt.subplots(figsize=(2, 2))
Pyrs.Agent.Environment.plot_environment(ax=sub_ax);

# %%
fig, sub_ax = plt.subplots(figsize=(2, 2))
Pyrs.Agent.Environment.plot_environment(ax=sub_ax);

# %% [markdown]
# ### Fig. 7: Multiple targets

# %% [markdown]
# A: environment with multiple objects
# B: object fields
# C: trajectory examples
# D: 5 examples PFs
# E: all place fields overlaid
# F: BTSP events
# G: relationship between visits and number of BTSP events

# %% [markdown]
# ### Fig. 8: Remapping

# %% [markdown]
# A: remapping
# B: remapped
# C: correlation pre post

# %% [markdown]
# ### Save figures

# %%
SAVE = True

# %%
if SAVE:
    print(f"Saving {len(ALL_FIGURES)} figures...")
    for key, ax in ALL_FIGURES.items():
        fig = ax.ravel()[0].figure if isinstance(ax, np.ndarray) else ax.figure
        plot_util.save_figure(fig, key, no_timestamp=True)
